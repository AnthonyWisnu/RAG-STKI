# %% [markdown]
# # KG-RAG Evaluation
#
# Notebook wrapper for the Day 13 evaluation script. Run the script cell to generate `raw_results.json` and `results.md`.

# %%
# !python ragas_eval.py --api-url http://127.0.0.1:8000
